# %%
# %sql
drop table if exists dev_analytics.db_317537.clm_ods_claims;

drop table if exists dev_analytics.db_317537.clm_ods_groups;
drop table if exists dev_analytics.db_317537.clm_ods_users;


drop table if exists dev_analytics.db_100001.cm_ods_amcrit;


delete from dev_analytics.db_100001.cm_ods_billacctmast where 1=1;

delete from dev_analytics.db_100001.cm_ods_amdet where 1=1;
