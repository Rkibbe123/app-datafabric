# %%
v_environment = dbutils.widgets.get("p_environment_name")

# %%
spark.sql(f"""
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_main;
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_main_dtm_dates;
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_main_plb_provider;
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_main_ref_identifications; --no cell block for this. 0 records

delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l2110_ref_claimlinerelatedidentifications; --all rows were labeled as bad. 0 records
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l2110_qty_claimlinesuplementalquantity; --all rows were labeled as bad. 0 records
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l2110_lq_claimlineremarks;
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l2110_dtm_claimlinedates; --all rows were labeled as bad. 0 records
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l2110_claimline;
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l2110_cas_claimlineadjustments;
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l2110_amt_claimlinesuplementalamount; --all rows were labeled as bad. 0 records

delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l2100_ref_claimrelatedidentifications;
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l2100_qty_claimsuplementalquantity;
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l2100_per_claimcontacts;
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l2100_nm1_claimnames;
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l2100_dtm_claimdates;
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l2100_claim;
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l2100_cas_claimadjustments;
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l2100_amt_claimsuplementalamount;

delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l2000_summary;

delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l1000b_ref_payeeadditionalidentifications;
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l1000b_rdm_payeedeliverymethod;
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l1000b_payee;
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l1000a_ref_payeradditionalidentification;
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l1000a_per_payercontacts;
delete from {v_environment}_analytics.db_000000_healthcareformats.t835_l1000a_payer;
""")
