# %% [markdown]
# # Databricks Smoke Test Notebook
# This notebook runs a basic test to verify the Databricks environment is operational after deployment.

# %%
# Simple environment check
import sys
print(f'Python version: {sys.version}')

# %%
# Spark session check
spark_version = spark.version
print(f'Spark version: {spark_version}')

# %%
# Simple DataFrame operation
df = spark.createDataFrame([(1, 'test')], ['id', 'value'])
df.show()

# %% [markdown]
# ---
# If all cells above run without error, the Databricks environment is healthy.
