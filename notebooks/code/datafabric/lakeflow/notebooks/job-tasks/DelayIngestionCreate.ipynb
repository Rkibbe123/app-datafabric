# %%
dbutils.widgets.text("p_ingestion_pipeline_name", "")

v_ingestion_pipeline_name = dbutils.widgets.get("p_ingestion_pipeline_name")

config_data_row_dict = dbutils.jobs.taskValues.get(taskKey="GetConfigPipelineData", key=v_ingestion_pipeline_name, debugValue=[v_ingestion_pipeline_name])

# %%
import time

# %%
v_default_sleep_time = 300 if config_data_row_dict['IngestionDelayStartinSeconds'] is None or config_data_row_dict['IngestionDelayStartinSeconds'] < 300 else config_data_row_dict['IngestionDelayStartinSeconds']

# Delay before Create Ingestion Pipeline
print(f"Waiting {v_default_sleep_time} seconds before Create Ingestion Pipeline {config_data_row_dict['IngestionPipelineName']}....")
time.sleep(v_default_sleep_time)
